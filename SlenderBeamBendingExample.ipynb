# %% [markdown]
# This example shows a Total Lagrangian formulation based on 8-node quadrilateral elements. A point force in vertical direction is applied to the right tip of the beam, createing bending-type large displacements.

# %%
import FEA
import importlib
importlib.reload(FEA)
import numpy as np

# ====================== Problem Setup ======================
mesh = FEA.LoadMesh("SlenderBeamBendingExample.msh", "quad8")
material = FEA.LinearElasticMaterial2D(E=8, nu=0.3)
discretization = FEA.Element8node2D()

# ====================== Dirichlet Boundary Conditions ======================
BC_fix_xdir = np.where(mesh.nodes[:, 1] == 0)[0]
BC_fix_ydir = BC_fix_xdir + mesh.ndofs_per_dimension
DirichletBC = FEA.DirichletBC(mesh, np.unique(np.concatenate([BC_fix_xdir, BC_fix_ydir])))

# ====================== Neumann Boundary Conditions ======================
# Find the node with maximum x and maximum y (tip corner)
index_tip = np.where((mesh.nodes[:, 0] == mesh.nodes[:, 0].max()) & (mesh.nodes[:, 1] == mesh.nodes[:, 1].max()))[0][0]
NeumannBC = FEA.NeumannBC().pointLoad(0, -2e-3, index_tip, mesh)

# ======================= TL Solver Setup =======================
U_history = FEA.GeometricNonlinearTL(mesh, material, discretization, DirichletBC, NeumannBC, steps=100)

# ======================= Post-Processing =======================
plt_original = FEA.DrawMesh2D(mesh, np.zeros(mesh.total_dofs), scale=1, title="Original Shape")
plt_deformed = FEA.DrawMesh2D(mesh, U_history[:, -1], scale=1, title="Deformed Shape at Final Step")
# Out:
# Converged at the outer iteration   1 with   5 inner iterations.
# Converged at the outer iteration   2 with   5 inner iterations.
# Converged at the outer iteration   3 with   5 inner iterations.
# Converged at the outer iteration   4 with   5 inner iterations.
# Converged at the outer iteration   5 with   5 inner iterations.
# Converged at the outer iteration   6 with   5 inner iterations.
# Converged at the outer iteration   7 with   7 inner iterations.
# Converged at the outer iteration   8 with  12 inner iterations.
# Converged at the outer iteration   9 with  13 inner iterations.
# Converged at the outer iteration  10 with  15 inner iterations.
# Converged at the outer iteration  11 with  10 inner iterations.
# Converged at the outer iteration  12 with   8 inner iterations.
# Converged at the outer iteration  13 with   8 inner iterations.
# Converged at the outer iteration  14 with   8 inner iterations.
# Converged at the outer iteration  15 with   8 inner iterations.
# Converged at the outer iteration  16 with   8 inner iterations.
# Converged at the outer iteration  17 with   7 inner iterations.
# Converged at the outer iteration  18 with   7 inner iterations.
# Converged at the outer iteration  19 with   7 inner iterations.
# Converged at the outer iteration  20 with   6 inner iterations.
# Converged at the outer iteration  21 with   6 inner iterations.
# Converged at the outer iteration  22 with   6 inner iterations.
# Converged at the outer iteration  23 with   6 inner iterations.
# Converged at the outer iteration  24 with   5 inner iterations.
# Converged at the outer iteration  25 with   5 inner iterations.
# Converged at the outer iteration  26 with   5 inner iterations.
# Converged at the outer iteration  27 with   5 inner iterations.
# Converged at the outer iteration  28 with   5 inner iterations.
# Converged at the outer iteration  29 with   5 inner iterations.
# Converged at the outer iteration  30 with   5 inner iterations.
# Converged at the outer iteration  31 with   5 inner iterations.
# Converged at the outer iteration  32 with   5 inner iterations.
# Converged at the outer iteration  33 with   5 inner iterations.
# Converged at the outer iteration  34 with   5 inner iterations.
# Converged at the outer iteration  35 with   5 inner iterations.
# Converged at the outer iteration  36 with   5 inner iterations.
# Converged at the outer iteration  37 with   5 inner iterations.
# Converged at the outer iteration  38 with   5 inner iterations.
# Converged at the outer iteration  39 with   5 inner iterations.
# Converged at the outer iteration  40 with   5 inner iterations.
# Converged at the outer iteration  41 with   5 inner iterations.
# Converged at the outer iteration  42 with   5 inner iterations.
# Converged at the outer iteration  43 with   5 inner iterations.
# Converged at the outer iteration  44 with   5 inner iterations.
# Converged at the outer iteration  45 with   5 inner iterations.
# Converged at the outer iteration  46 with   5 inner iterations.
# Converged at the outer iteration  47 with   5 inner iterations.
# Converged at the outer iteration  48 with   5 inner iterations.
# Converged at the outer iteration  49 with   5 inner iterations.
# Converged at the outer iteration  50 with   5 inner iterations.
# Converged at the outer iteration  51 with   5 inner iterations.
# Converged at the outer iteration  52 with   5 inner iterations.
# Converged at the outer iteration  53 with   4 inner iterations.
# Converged at the outer iteration  54 with   4 inner iterations.
# Converged at the outer iteration  55 with   4 inner iterations.
# Converged at the outer iteration  56 with   4 inner iterations.
# Converged at the outer iteration  57 with   4 inner iterations.
# Converged at the outer iteration  58 with   4 inner iterations.
# Converged at the outer iteration  59 with   4 inner iterations.
# Converged at the outer iteration  60 with   4 inner iterations.
# Converged at the outer iteration  61 with   4 inner iterations.
# Converged at the outer iteration  62 with   4 inner iterations.
# Converged at the outer iteration  63 with   4 inner iterations.
# Converged at the outer iteration  64 with   4 inner iterations.
# Converged at the outer iteration  65 with   3 inner iterations.
# Converged at the outer iteration  66 with   3 inner iterations.
# Converged at the outer iteration  67 with   3 inner iterations.
# Converged at the outer iteration  68 with   3 inner iterations.
# Converged at the outer iteration  69 with   3 inner iterations.
# Converged at the outer iteration  70 with   3 inner iterations.
# Converged at the outer iteration  71 with   3 inner iterations.
# Converged at the outer iteration  72 with   3 inner iterations.
# Converged at the outer iteration  73 with   3 inner iterations.
# Converged at the outer iteration  74 with   3 inner iterations.
# Converged at the outer iteration  75 with   3 inner iterations.
# Converged at the outer iteration  76 with   3 inner iterations.
# Converged at the outer iteration  77 with   3 inner iterations.
# Converged at the outer iteration  78 with   3 inner iterations.
# Converged at the outer iteration  79 with   3 inner iterations.
# Converged at the outer iteration  80 with   3 inner iterations.
# Converged at the outer iteration  81 with   3 inner iterations.
# Converged at the outer iteration  82 with   3 inner iterations.
# Converged at the outer iteration  83 with   3 inner iterations.
# Converged at the outer iteration  84 with   3 inner iterations.
# Converged at the outer iteration  85 with   3 inner iterations.
# Converged at the outer iteration  86 with   3 inner iterations.
# Converged at the outer iteration  87 with   3 inner iterations.
# Converged at the outer iteration  88 with   3 inner iterations.
# Converged at the outer iteration  89 with   3 inner iterations.
# Converged at the outer iteration  90 with   3 inner iterations.
# Converged at the outer iteration  91 with   3 inner iterations.
# Converged at the outer iteration  92 with   3 inner iterations.
# Converged at the outer iteration  93 with   3 inner iterations.
# Converged at the outer iteration  94 with   3 inner iterations.
# Converged at the outer iteration  95 with   3 inner iterations.
# Converged at the outer iteration  96 with   3 inner iterations.
# Converged at the outer iteration  97 with   3 inner iterations.
# Converged at the outer iteration  98 with   3 inner iterations.
# Converged at the outer iteration  99 with   3 inner iterations.
# Converged at the outer iteration 100 with   3 inner iterations.
